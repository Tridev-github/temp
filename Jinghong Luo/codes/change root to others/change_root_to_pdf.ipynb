# %%
import ROOT as rt
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.cm

# 设置色图
my_cmap = matplotlib.cm.get_cmap('turbo')

# ROOT 设置
rt.gROOT.SetBatch(True)
infile = rt.TFile("mosaic/mosaic.root")

# %%
#infile = rt.TFile("ljh_folder/ljhmac/5hole/5hole.root")
#ppdfs_list=[]
N_fov=(100,100)

tree_singles1 = infile.Singles_crystal1
htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
tree_singles1.Draw("sourcePosY:sourcePosX>>htmp", "", "goff")
#ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
#del htmp

for i in range(1, 36):
    #htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
    tree_name = f"Singles_crystal1_run{i}"
    tree = getattr(infile, tree_name)
    tree.Draw("sourcePosY:sourcePosX>>+htmp","","goff")
    #ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
    #del htmp

tree_singles2 = infile.Singles_crystal2
#htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
tree_singles2.Draw("sourcePosY:sourcePosX>>+htmp", "", "goff")
#ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
#del htmp

for i in range(1, 36):
    #htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
    tree_name = f"Singles_crystal2_run{i}"
    tree = getattr(infile, tree_name)
    tree.Draw("sourcePosY:sourcePosX>>+htmp","","goff")
    #ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
    #del htmp

tree_singles3 = infile.Singles_crystal3
#htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
tree_singles3.Draw("sourcePosY:sourcePosX>>+htmp", "", "goff")
#ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
#del htmp

for i in range(1, 36):
    #htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
    tree_name = f"Singles_crystal3_run{i}"
    tree = getattr(infile, tree_name)
    tree.Draw("sourcePosY:sourcePosX>>+htmp","","goff")
    #ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
    #del htmp

tree_singles4 = infile.Singles_crystal4
#htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
tree_singles4.Draw("sourcePosY:sourcePosX>>+htmp", "", "goff")
#ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
#del htmp

for i in range(1, 36):
    #htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
    tree_name = f"Singles_crystal4_run{i}"
    tree = getattr(infile, tree_name)
    tree.Draw("sourcePosY:sourcePosX>>+htmp","","goff")
    #ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
    #del htmp

tree_singles5 = infile.Singles_crystal5
#htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
tree_singles5.Draw("sourcePosY:sourcePosX>>+htmp", "", "goff")
#ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
#del htmp

for i in range(1, 36):
    #htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
    tree_name = f"Singles_crystal5_run{i}"
    tree = getattr(infile, tree_name)
    tree.Draw("sourcePosY:sourcePosX>>+htmp","","goff")
    #ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
    #del htmp

tree_singles6 = infile.Singles_crystal6
#htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
tree_singles6.Draw("sourcePosY:sourcePosX>>+htmp", "", "goff")
#ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
#del htmp

for i in range(1, 36):
    #htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
    tree_name = f"Singles_crystal6_run{i}"
    tree = getattr(infile, tree_name)
    tree.Draw("sourcePosY:sourcePosX>>+htmp","","goff")
    #ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
    #del htmp

tree_singles7 = infile.Singles_crystal7
#htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
tree_singles7.Draw("sourcePosY:sourcePosX>>+htmp", "", "goff")
#ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
#del htmp

for i in range(1, 36):
    #htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
    tree_name = f"Singles_crystal7_run{i}"
    tree = getattr(infile, tree_name)
    tree.Draw("sourcePosY:sourcePosX>>+htmp","","goff")
    #ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
    #del htmp

tree_singles8 = infile.Singles_crystal8
#htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
tree_singles8.Draw("sourcePosY:sourcePosX>>+htmp", "", "goff")
#ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
#del htmp

for i in range(1, 36):
    #htmp=rt.TH2D("htmp","htmp",N_fov[0],-N_fov[0]//2,N_fov[0]//2,N_fov[1],-N_fov[1]//2,N_fov[1]//2)
    tree_name = f"Singles_crystal8_run{i}"
    tree = getattr(infile, tree_name)
    tree.Draw("sourcePosY:sourcePosX>>+htmp","","goff")
    #ppdfs_list.append(np.array(htmp).reshape((N_fov[0]+2,N_fov[1]+2))[1:-1,1:-1])
    #del htmp

# %%
# 读取 Singles 树
#tree_singles = infile.Singles_crystal1

# 创建一个2D直方图，用于累积所有树的数据
#hmapAll = rt.TH2F("hmapAll", "hmapAll", 100, -50, 50, 100, -50, 50)
#print(hmapAll.GetEntries())
# 将 Singles 树中的数据填充到直方图中
#tree_singles.Draw("sourcePosY:sourcePosX>>hmapAll","", "goff")
#print(hmapAll.GetEntries())
# 使用循环读取并累积 Singles_run1 到 Singles_run359 的数据
#for i in range(1, 60):
 #   tree_name = f"Singles_run{i}"
  #  tree = getattr(infile, tree_name)
   # tree.Draw("sourcePosY:sourcePosX>>+hmapAll", "", "goff")

# 将ROOT直方图转换为NumPy数组进行处理
mapAll = np.reshape(np.array(htmp), (102, 102))[1:-1, 1:-1] 
np.set_printoptions(threshold=np.inf)
# 打印数组的平均值
#print(np.sum(mapAll))
#print(mapAll)

# 创建Matplotlib图形对象
fig, ax = plt.subplots(figsize=(10, 9))
imshow_obj = ax.imshow(mapAll, cmap=my_cmap, origin='lower')

# 添加颜色条
cbar = plt.colorbar(imshow_obj)

# 设置图形标题和轴标签
plt.suptitle("All Recorded Singles and Singles_run1 to Singles_run35 in Monte Carlo Simulation")
ax.set_xlabel("Image Space Pixel X-Index")
ax.set_ylabel("Image Space Pixel Y-Index ")

# 调整布局并保存图像
fig.tight_layout()
fig.savefig("mosaicSPECT.pdf")

# 如果需要显示图像，取消注释下面的行
#plt.show()
#infile.Close()

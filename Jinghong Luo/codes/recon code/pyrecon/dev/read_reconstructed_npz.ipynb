# %%
import numpy
import matplotlib.pyplot as plt

# %%
reconstructed = numpy.load("../data/test_reconstruction.npz")['reconstructed']
#projection = reconstructed.reshape((10000,1))

# %%
#print(projection.shape)
#print(numpy.sum(projection))

# %%
fig, ax = plt.subplots(figsize=(16, 10))
ax.imshow(numpy.reshape(reconstructed,(100,100)), cmap='gray')

# %%
phantom = numpy.load("../data/center3.npz")['phantom']
fig, ax = plt.subplots(figsize=(16, 10))
ax.imshow(numpy.reshape(phantom,(100,100)), cmap='gray')

# %%
print(projection)
# Out:
# [[nan]
#  [nan]
#  [nan]
#  ...
#  [nan]
#  [nan]
#  [nan]]

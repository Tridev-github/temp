# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# projection = np.load('../data/1SPECT_phantom_projection.npz')
data = np.load('../data/5hole_projection.npz')

# %%
fig, ax = plt.subplots(1, 1, figsize=(26, 12))
projection = data['projection'].reshape((180,1))
# fig.colorbar(ax.imshow(projection['projection'], cmap='gray', aspect='equal',origin='lower'))
fig.colorbar(ax.imshow(projection, cmap='gray', aspect='equal',origin='lower'))

# %%
np.set_printoptions(threshold=np.inf)
print(projection)
# Out:
# [[752.]
#  [836.]
#  [774.]
#  [759.]
#  [789.]
#  [740.]
#  [787.]
#  [781.]
#  [695.]
#  [763.]
#  [755.]
#  [774.]
#  [801.]
#  [723.]
#  [746.]
#  [740.]
#  [761.]
#  [758.]
#  [766.]
#  [734.]
#  [738.]
#  [728.]
#  [788.]
#  [772.]
#  [718.]
#  [767.]
#  [743.]
#  [739.]
#  [792.]
#  [786.]
#  [761.]
#  [749.]
#  [799.]
#  [797.]
#  [771.]
#  [748.]
#  [774.]
#  [808.]
#  [788.]
#  [810.]
#  [791.]
#  [771.]
#  [783.]
#  [728.]
#  [757.]
#  [803.]
#  [783.]
#  [806.]
#  [782.]
#  [788.]
#  [816.]
#  [778.]
#  [837.]
#  [790.]
#  [817.]
#  [795.]
#  [820.]
#  [811.]
#  [772.]
#  [810.]
#  [818.]
#  [807.]
#  [791.]
#  [818.]
#  [753.]
#  [804.]
#  [756.]
#  [758.]
#  [803.]
#  [813.]
#  [812.]
#  [818.]
#  [788.]
#  [811.]
#  [800.]
#  [810.]
#  [768.]
#  [736.]
#  [796.]
#  [758.]
#  [804.]
#  [772.]
#  [772.]
#  [773.]
#  [738.]
#  [819.]
#  [703.]
#  [723.]
#  [835.]
#  [777.]
#  [826.]
#  [788.]
#  [793.]
#  [791.]
#  [753.]
#  [792.]
#  [789.]
#  [823.]
#  [807.]
#  [765.]
# ...
